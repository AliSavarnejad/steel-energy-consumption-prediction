# %% [markdown]
# # Steel Industry Energy Consumption Prediction
#
# ## Project Goal
# This project aims to analyze and predict energy consumption in a steel industry setting using machine learning.
#
# ## Objectives
# - inspect and understand the dataset
# - identify important variables
# - explore data quality and missing values
# - prepare for regression modeling

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

print("Industrial AI project environment ready")
# Out:
# Industrial AI project environment ready
